# %%
#Getting Started - Loading Libraries
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# '/Users/jonzimmerman/Desktop/Data Projects/Chicago Face Database'

# %%
#Load data
os.chdir('/Users/jonzimmerman/Desktop/Data Projects/OT Data Analysis')

# %%
data=pd.read_excel('OrangeTheoryData.xlsx')

# %%
data.head()
# Out:
#    VisitNum  VisitNum_Month       Date  ClassLength  Splat  Calories  AvgHR  \
# 0         1               3 2019-03-14    55.000000    1.0     565.0    122
# 1         2               3 2019-03-21    58.000000    1.0     586.0    121
# 2         3               3 2019-03-28    57.000000    2.0     638.0    128
# 3         4               3 2019-04-04    57.000000    8.0     601.0    124
# 4         5               3 2019-04-09    57.033333    9.0     542.0    117
#
#    MaxHR  GrayMin    BlueMin  ...  Calories_Splat  Visits_Studio  SH_12 FH_12  \
# 0    165    18.00  20.000000  ...      565.000000             35      0     0
# 1    167    16.00  17.000000  ...      586.000000             35      0     0
# 2    169    13.00  17.000000  ...      319.000000             35      0     0
# 3    169    25.90   5.266667  ...       75.125000             35      0     0
# 4    177    26.65  13.916667  ...       60.222222             35      0     0
#
#     MIN_CAL BellCurve  Visits_Trainer   MONYEAR   Latitude  Longitude
# 0  0.097345         0              13  MAR 2019  38.881885 -77.229702
# 1  0.098976         1              13  MAR 2019  38.881885 -77.229702
# 2  0.089342         1              10  MAR 2019  38.881885 -77.229702
# 3  0.094842         0              13  APR 2019  38.881885 -77.229702
# 4  0.105228         0               2  APR 2019  38.881885 -77.229702
#
# [5 rows x 51 columns]

# %%
data.columns
# Out:
# Index(['VisitNum', 'VisitNum_Month', 'Date', 'ClassLength', 'Splat',
#        'Calories', 'AvgHR', 'MaxHR', 'GrayMin', 'BlueMin', 'GreenMin',
#        'OrangeMin', 'RedMin', 'Location', 'Time', 'Trainer', 'DaysSince',
#        'Gain_Loss_Correct', 'Mon_Yr', 'Weekday', 'Twelve_or_Above',
#        'MIN _SPLAT', 'Correct', 'Gain', 'Loss', 'Gray_Perc', 'Blue_Perc',
#        'Green_Perc', 'Orange_Perc', 'Red_Perc', 'Monthly_Cost',
#        'Cost_Per_Class', 'Calories_Month', 'SplatPts_Month', 'Year',
#        'ExtraExpenses', 'Goal', 'CAL_MIN', 'Morn_Even', 'Week_Month', 'Month',
#        'Calories_Splat', 'Visits_Studio', 'SH_12', 'FH_12', 'MIN_CAL',
#        'BellCurve', 'Visits_Trainer', 'MONYEAR', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.shape
# Out:
# (143, 51)

# %%
data.isna().sum()
# Out:
# VisitNum               0
# VisitNum_Month         0
# Date                   0
# ClassLength            0
# Splat                  0
# Calories               0
# AvgHR                  0
# MaxHR                  0
# GrayMin                0
# BlueMin                0
# GreenMin               0
# OrangeMin              0
# RedMin                 0
# Location               0
# Time                   0
# Trainer                0
# DaysSince              1
# Gain_Loss_Correct      0
# Mon_Yr                 0
# Weekday                0
# Twelve_or_Above        0
# MIN _SPLAT             0
# Correct                0
# Gain                   0
# Loss                   0
# Gray_Perc              0
# Blue_Perc              0
# Green_Perc             0
# Orange_Perc            0
# Red_Perc               0
# Monthly_Cost           0
# Cost_Per_Class         0
# Calories_Month         0
# SplatPts_Month         0
# Year                   0
# ExtraExpenses        138
# Goal                   0
# CAL_MIN                0
# Morn_Even              0
# Week_Month             0
# Month                  0
# Calories_Splat         0
# Visits_Studio          0
# SH_12                  0
# FH_12                  0
# MIN_CAL                0
# BellCurve              0
# Visits_Trainer         0
# MONYEAR                0
# Latitude               0
# Longitude              0
# dtype: int64

# %%
data.count()
# Out:
# VisitNum             143
# VisitNum_Month       143
# Date                 143
# ClassLength          143
# Splat                143
# Calories             143
# AvgHR                143
# MaxHR                143
# GrayMin              143
# BlueMin              143
# GreenMin             143
# OrangeMin            143
# RedMin               143
# Location             143
# Time                 143
# Trainer              143
# DaysSince            142
# Gain_Loss_Correct    143
# Mon_Yr               143
# Weekday              143
# Twelve_or_Above      143
# MIN _SPLAT           143
# Correct              143
# Gain                 143
# Loss                 143
# Gray_Perc            143
# Blue_Perc            143
# Green_Perc           143
# Orange_Perc          143
# Red_Perc             143
# Monthly_Cost         143
# Cost_Per_Class       143
# Calories_Month       143
# SplatPts_Month       143
# Year                 143
# ExtraExpenses          5
# Goal                 143
# CAL_MIN              143
# Morn_Even            143
# Week_Month           143
# Month                143
# Calories_Splat       143
# Visits_Studio        143
# SH_12                143
# FH_12                143
# MIN_CAL              143
# BellCurve            143
# Visits_Trainer       143
# MONYEAR              143
# Latitude             143
# Longitude            143
# dtype: int64

# %%
data.describe()
# Out:
#         VisitNum  VisitNum_Month  ClassLength       Splat    Calories  \
# count  143.00000      143.000000   143.000000  143.000000  143.000000
# mean    72.00000       13.223776    57.069580   13.566434  611.909091
# std     41.42463        3.818818     2.349830    4.374316   50.525535
# min      1.00000        3.000000    48.666667    0.000000  447.000000
# 25%     36.50000       11.000000    55.850000   11.000000  577.000000
# 50%     72.00000       14.000000    57.133333   14.000000  610.000000
# 75%    107.50000       16.000000    58.591667   16.000000  647.500000
# max    143.00000       17.000000    62.866667   23.000000  725.000000
#
#             AvgHR       MaxHR     GrayMin     BlueMin    GreenMin  ...  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  ...
# mean   125.531469  169.244755   15.279371   12.807809   15.450000  ...
# std      5.796799    4.383414    7.122928    4.244671    5.665112  ...
# min    110.000000  146.000000    3.983333    3.383333    5.566667  ...
# 25%    121.000000  167.000000    8.725000   10.241667   11.258333  ...
# 50%    126.000000  169.000000   14.200000   12.800000   15.433333  ...
# 75%    130.000000  172.000000   20.958333   15.300000   19.375000  ...
# max    139.000000  187.000000   31.566667   25.500000   32.833333  ...
#
#             Month  Calories_Splat  Visits_Studio       SH_12       FH_12  \
# count  143.000000      143.000000     143.000000  143.000000  143.000000
# mean     6.937063       56.618870      35.181818    0.412587    0.699301
# std      3.709935       67.698347      14.095068    0.494030    0.460174
# min      1.000000        0.000000       1.000000    0.000000    0.000000
# 25%      3.000000       37.031250      35.000000    0.000000    0.000000
# 50%      8.000000       43.928571      37.000000    0.000000    1.000000
# 75%     10.000000       55.644444      48.000000    1.000000    1.000000
# max     12.000000      586.000000      48.000000    1.000000    1.000000
#
#           MIN_CAL   BellCurve  Visits_Trainer    Latitude   Longitude
# count  143.000000  143.000000      143.000000  143.000000  143.000000
# mean     0.093816    0.258741       13.265734   38.926764  -77.042523
# std      0.007770    0.439483        9.820897    0.215330    0.368960
# min      0.078994    0.000000        1.000000   38.879828  -77.229702
# 25%      0.088203    0.000000        4.000000   38.881885  -77.072693
# 50%      0.092383    0.000000       12.000000   38.903510  -77.051809
# 75%      0.099271    1.000000       20.000000   38.916487  -77.031514
# max      0.119016    1.000000       29.000000   40.724211  -74.036191
#
# [8 rows x 41 columns]

# %%
#Plot data
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.barplot(x="Location",y="Calories",data=data)

# %%
sns.barplot(x="Location",y="Calories_Splat",data=data)

# %%
sns.barplot(x="Location",y="Green_Perc",data=data)

# %%
viz2a=sns.kdeplot(data.Calories,data.Splat,
               shade=True,shade_lowest=False,cmap='Greens')
viz2b=sns.kdeplot(data.Calories,data.Splat,cmap='Greens')

sns.set()
j=sns.jointplot(data=data,x='Calories',y='Splat')

# %%
#Run a Poisson Regression Model on Calories Burned
from patsy import dmatrices
import statsmodels.api as sm

formula = """Calories ~ C(Location)+ AvgHR + DaysSince + ClassLength + Splat"""
response, predictors = dmatrices(formula, data, return_type='dataframe')
po_results = sm.GLM(response, predictors, family=sm.families.Poisson()).fit()
print(po_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               Calories   No. Observations:                  142
# Model:                            GLM   Df Residuals:                      128
# Model Family:                 Poisson   Df Model:                           13
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -587.45
# Date:                Sun, 10 May 2020   Deviance:                       3.1449
# Time:                        11:43:05   Pearson chi2:                     3.14
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       3.6696      0.136     26.895      0.000       3.402       3.937
# C(Location)[T.Cleveland Park, DC]              -0.0005      0.046     -0.010      0.992      -0.091       0.090
# C(Location)[T.Dunn Lorring, VA]                 0.0028      0.010      0.272      0.786      -0.018       0.023
# C(Location)[T.Foggy Bottom, DC]                 0.0015      0.010      0.155      0.877      -0.017       0.020
# C(Location)[T.Georgetown, DC]                   0.0064      0.025      0.261      0.794      -0.042       0.055
# C(Location)[T.Jersey City, NJ]                  0.0057      0.029      0.197      0.844      -0.051       0.062
# C(Location)[T.Mt. Vernon Triangle/Shaw, DC]     0.0030      0.025      0.122      0.903      -0.045       0.051
# C(Location)[T.Navy Yard, DC]                   -0.0013      0.015     -0.084      0.933      -0.031       0.028
# C(Location)[T.Rosslyn, VA]                     -0.0050      0.040     -0.126      0.900      -0.083       0.073
# C(Location)[T.Thomas Circle, DC]                0.0002      0.024      0.009      0.993      -0.047       0.048
# AvgHR                                           0.0139      0.001     20.210      0.000       0.013       0.015
# DaysSince                                    1.859e-05      0.002      0.012      0.990      -0.003       0.003
# ClassLength                                     0.0174      0.002     10.534      0.000       0.014       0.021
# Splat                                        4.941e-05      0.001      0.049      0.961      -0.002       0.002
# ===============================================================================================================

# %%
#Condense Location categories down to only studios with at least 4 visits
data.Location.unique()
data["Location"].value_counts()
# Out:
# 14th Street, DC                 48
# Foggy Bottom, DC                37
# Dunn Lorring, VA                35
# Navy Yard, DC                   10
# Mt. Vernon Triangle/Shaw, DC     3
# Thomas Circle, DC                3
# Georgetown, DC                   3
# Jersey City, NJ                  2
# Rosslyn, VA                      1
# Cleveland Park, DC               1
# Name: Location, dtype: int64

# %%
data['StudioCounts'] = data['Location'].map(data['Location'].value_counts())
def f(row):
    if row['StudioCounts'] >= 4:
        Location2 = row['Location']
    elif row['StudioCounts'] < 4:
        Location2 = "Other"
    return Location2

# %%
data['Location2'] = data.apply(f, axis=1)
data["Location2"].value_counts()
# Out:
# 14th Street, DC     48
# Foggy Bottom, DC    37
# Dunn Lorring, VA    35
# Other               13
# Navy Yard, DC       10
# Name: Location2, dtype: int64

# %%
#Condense Trainer categories down to only trainers with at least 4 visits
data['TrainerCounts'] = data['Trainer'].map(data['Trainer'].value_counts())
def f(row):
    if row['TrainerCounts'] >= 3:
        Trainer2 = row['Trainer']
    elif row['TrainerCounts'] < 3:
        Trainer2 = "Other"
    return Trainer2

# %%
data['Trainer2'] = data.apply(f, axis=1)
data["Trainer2"].value_counts()
# Out:
# Tiffany    28
# Other      28
# Damani     20
# Audrey     13
# Demi       12
# Kandace    10
# Joe         9
# Marcus      8
# Kara        5
# Darrell     4
# Rachel2     3
# Luke        3
# Name: Trainer2, dtype: int64

# %%
sns.barplot(x="Location2",y="Splat",data=data)

# %%
sns.barplot(x="Trainer2",y="Splat",data=data)

# %%
#Rerun Poisson Regression model with new trainer and location variables
formula = """Calories ~ C(Trainer2, Treatment('Other'))+C(Location2, Treatment('Other'))+ AvgHR + DaysSince + ClassLength + Splat"""
response, predictors = dmatrices(formula, data, return_type='dataframe')
po_results = sm.GLM(response, predictors, family=sm.families.Poisson()).fit()
print(po_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               Calories   No. Observations:                  142
# Model:                            GLM   Df Residuals:                      122
# Model Family:                 Poisson   Df Model:                           19
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -587.31
# Date:                Sun, 10 May 2020   Deviance:                       2.8658
# Time:                        11:44:12   Pearson chi2:                     2.86
# No. Iterations:                     4
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                                3.6853      0.144     25.659      0.000       3.404       3.967
# C(Trainer2, Treatment('Other'))[T.Audrey]                0.0011      0.019      0.056      0.955      -0.036       0.038
# C(Trainer2, Treatment('Other'))[T.Damani]               -0.0029      0.019     -0.151      0.880      -0.040       0.034
# C(Trainer2, Treatment('Other'))[T.Darrell]              -0.0037      0.025     -0.145      0.885      -0.053       0.046
# C(Trainer2, Treatment('Other'))[T.Demi]                 -0.0024      0.018     -0.134      0.894      -0.038       0.033
# C(Trainer2, Treatment('Other'))[T.Joe]                   0.0083      0.046      0.181      0.856      -0.082       0.099
# C(Trainer2, Treatment('Other'))[T.Kandace]               0.0001      0.019      0.008      0.994      -0.038       0.038
# C(Trainer2, Treatment('Other'))[T.Kara]                 -0.0004      0.024     -0.017      0.986      -0.048       0.047
# C(Trainer2, Treatment('Other'))[T.Luke]                 -0.0098      0.032     -0.310      0.757      -0.072       0.052
# C(Trainer2, Treatment('Other'))[T.Marcus]               -0.0031      0.022     -0.141      0.888      -0.046       0.040
# C(Trainer2, Treatment('Other'))[T.Rachel2]               0.0043      0.027      0.160      0.873      -0.049       0.057
# C(Trainer2, Treatment('Other'))[T.Tiffany]               0.0024      0.018      0.137      0.891      -0.032       0.037
# C(Location2, Treatment('Other'))[T.14th Street, DC]     -0.0018      0.021     -0.089      0.929      -0.042       0.039
# C(Location2, Treatment('Other'))[T.Dunn Lorring, VA]     0.0016      0.020      0.081      0.936      -0.038       0.041
# C(Location2, Treatment('Other'))[T.Foggy Bottom, DC]     0.0021      0.021      0.100      0.921      -0.040       0.044
# C(Location2, Treatment('Other'))[T.Navy Yard, DC]       -0.0107      0.046     -0.234      0.815      -0.101       0.079
# AvgHR                                                    0.0138      0.001     19.023      0.000       0.012       0.015
# DaysSince                                               -0.0001      0.002     -0.078      0.938      -0.003       0.003
# ClassLength                                              0.0174      0.002      9.897      0.000       0.014       0.021
# Splat                                                    0.0001      0.001      0.114      0.909      -0.002       0.002
# ========================================================================================================================

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = data['Location2'].unique()
sizes = (data['Location2'].value_counts().sort_index()/data['Location2'].value_counts().sum())*100

# Plot
plt.pie(sizes, labels=sizes.index,
autopct='%1.1f%%', shadow=True, startangle=240)

plt.axis('equal')
#plt.legend(sizes.index, loc="best")
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = data['Weekday'].unique()
sizes = (data['Weekday'].value_counts().sort_index()/data['Weekday'].value_counts().sum())*100

# Plot
plt.pie(sizes, labels=sizes.index,
autopct='%1.1f%%', shadow=True, startangle=100)

plt.axis('equal')
#plt.legend(sizes.index, loc="best")
plt.tight_layout()

plt.show()

# %%
data.columns
# Out:
# Index(['VisitNum', 'VisitNum_Month', 'Date', 'ClassLength', 'Splat',
#        'Calories', 'AvgHR', 'MaxHR', 'GrayMin', 'BlueMin', 'GreenMin',
#        'OrangeMin', 'RedMin', 'Location', 'Time', 'Trainer', 'DaysSince',
#        'Gain_Loss_Correct', 'Mon_Yr', 'Weekday', 'Twelve_or_Above',
#        'MIN _SPLAT', 'Correct', 'Gain', 'Loss', 'Gray_Perc', 'Blue_Perc',
#        'Green_Perc', 'Orange_Perc', 'Red_Perc', 'Monthly_Cost',
#        'Cost_Per_Class', 'Calories_Month', 'SplatPts_Month', 'Year',
#        'ExtraExpenses', 'Goal', 'CAL_MIN', 'Morn_Even', 'Week_Month', 'Month',
#        'Calories_Splat', 'Visits_Studio', 'SH_12', 'FH_12', 'MIN_CAL',
#        'BellCurve', 'Visits_Trainer', 'MONYEAR', 'Latitude', 'Longitude',
#        'StudioCounts', 'Location2', 'TrainerCounts', 'Trainer2'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = data['DaysSince'].unique()
sizes = (data['DaysSince'].value_counts().sort_index()/data['DaysSince'].value_counts().sum())*100

# Plot
plt.pie(sizes, labels=sizes.index,
autopct='%1.1f%%', shadow=True, startangle=100)

plt.axis('equal')
#plt.legend(sizes.index, loc="best")
plt.tight_layout()

plt.show()
